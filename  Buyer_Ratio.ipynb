# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b0373b1f-9ce4-4135-afdc-0deed50e9255" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0373b1f-9ce4-4135-afdc-0deed50e9255">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Buyer Ratio.csv to Buyer Ratio.csv

# %%
import pandas as pd
import io

# %%
import numpy as np
from scipy import stats

# %%
df = pd.read_csv(io.BytesIO(uploaded['Buyer Ratio.csv']))
print(df)
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
df_table=df.iloc[:,1:6]
df_table
# Out:
#    East  West  North  South
# 0    50   142    131     70
# 1   435  1523   1356    750

# %%
df_table.values
# Out:
# array([[  50,  142,  131,   70],
#        [ 435, 1523, 1356,  750]])

# %%
val=stats.chi2_contingency(df_table)

# %%
val
# Out:
# (1.595945538661058,
#  0.6603094907091882,
#  3,
#  array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#         [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
type(val)
# Out:
# tuple

# %%
no_of_rows=len(df_table.iloc[0:2,0])
no_of_columns=len(df_table.iloc[0,0:4])
degree_of_f=(no_of_rows-1)*(no_of_columns-1)
print('Degree of Freedom=', degree_of_f)
# Out:
# Degree of Freedom= 3

# %%
Expected_value=val[3]

# %%
Expected_value
# Out:
# array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]])

# %%
from scipy.stats import chi2
chi_square=sum([(o-e)**2/e for o,e in zip(df_table.values,Expected_value)])
chi_square_statestic=chi_square[0]+chi_square[1]
chi_square_statestic
# Out:
# 1.5152956451130446

# %%
critical_value=chi2.ppf(0.95,3)
critical_value
# Out:
# 7.814727903251179

# %%
print ('Dependent (reject H0)')
print ('Independent (fail to reject H0)')
# Out:
# Dependent (reject H0)
# Independent (fail to reject H0)

# %%
pvalue=1-chi2.cdf(chi_square_statestic,3)
pvalue
# Out:
# 0.6787446296467897

# %%
#failed to reject null hypothesis
